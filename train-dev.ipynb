# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
from model import *
from train import read_data, get_batch, estimate_loss

# %%
input = read_data()
chars=sorted(list(set(input)))
print(''.join(chars))
print(len(chars))
vocab_size=len(chars)
# Begin with a character-level tokenizer
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])

data = torch.tensor(encode(input), dtype=torch.long)

n=int(0.9*len(data))
train_data=data[:n]
val_data=data[n:]

def get_batch(split):
    data = train_data if split=='train' else val_data
    ix = torch.randint(len(data) - max_seq_len, (batch_size,))
    x = torch.stack([data[i:i+max_seq_len] for i in ix])
    y = torch.stack([data[i+1:i+max_seq_len+1] for i in ix])
    return x,y

@torch.no_grad()
def estimate_loss(model):
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out
# Out:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# 65

# %%
xb, yb = get_batch('train')
print(xb)
print(yb)
# Out:
# tensor([[52, 42, 57,  1, 51, 43,  1, 61, 47, 58, 46,  1, 58, 46, 43,  1],
#         [ 6,  1, 61, 47, 50, 58,  1, 58, 46, 53, 59,  1, 50, 43, 39, 60],
#         [53,  1, 53, 59, 56,  1, 54, 56, 53, 41, 43, 43, 42, 47, 52, 45],
#         [59, 57,  1, 25, 39, 56, 41, 47, 59, 57, 11,  1, 58, 46, 43, 57],
#         [46, 43, 56,  5, 57,  1, 42, 43, 39, 58, 46,  0, 32, 39, 49, 43],
#         [52,  1, 46, 53, 61,  1, 55, 59, 47, 41, 49, 50, 63,  1, 57, 46],
#         [50, 63,  1, 53, 39, 58, 46, 10,  0, 32, 53,  1, 49, 43, 43, 54],
#         [43, 44, 43, 56, 51, 43, 52, 58,  1, 42, 56, 53, 54,  1, 53, 52]])
# tensor([[42, 57,  1, 51, 43,  1, 61, 47, 58, 46,  1, 58, 46, 43,  1, 44],
#         [ 1, 61, 47, 50, 58,  1, 58, 46, 53, 59,  1, 50, 43, 39, 60, 43],
#         [ 1, 53, 59, 56,  1, 54, 56, 53, 41, 43, 43, 42, 47, 52, 45, 57],
#         [57,  1, 25, 39, 56, 41, 47, 59, 57, 11,  1, 58, 46, 43, 57, 43],
#         [43, 56,  5, 57,  1, 42, 43, 39, 58, 46,  0, 32, 39, 49, 43,  1],
#         [ 1, 46, 53, 61,  1, 55, 59, 47, 41, 49, 50, 63,  1, 57, 46, 53],
#         [63,  1, 53, 39, 58, 46, 10,  0, 32, 53,  1, 49, 43, 43, 54,  1],
#         [44, 43, 56, 51, 43, 52, 58,  1, 42, 56, 53, 54,  1, 53, 52,  1]])

# %%
mod = GPTDecoderModel(vocab_size)
mod = mod.to(device)
print(sum(p.numel() for p in mod.parameters())/1e6, 'M parameters')
# Out:
# 18.969665 M parameters

# %%
optimizer = torch.optim.Adam(mod.parameters(), lr=lr)
max_iters=10000
for iter in range(max_iters):

    if iter % 50 == 0 or iter == max_iters-1:
        losses = estimate_loss(mod)
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
    
    xb, yb = get_batch('train')
    
    logits, loss = mod(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 1.7808, val loss 1.9501
# step 50: train loss 1.8076, val loss 1.9216
# step 100: train loss 1.8088, val loss 1.9542
# step 150: train loss 1.7942, val loss 1.9233
# step 200: train loss 1.7932, val loss 1.9516
# step 250: train loss 1.7759, val loss 1.9549
# step 300: train loss 1.7709, val loss 1.9238
# step 350: train loss 1.8036, val loss 1.9398
# step 400: train loss 1.7555, val loss 1.9144
# step 450: train loss 1.7770, val loss 1.9324
# step 500: train loss 1.7942, val loss 1.9329
# step 550: train loss 1.7742, val loss 1.9261
# step 600: train loss 1.7870, val loss 1.9355
# step 650: train loss 1.7714, val loss 1.9182
# step 700: train loss 1.7697, val loss 1.9043
# step 750: train loss 1.7543, val loss 1.9258
# step 800: train loss 1.7389, val loss 1.9037
# step 850: train loss 1.7561, val loss 1.9114
# step 900: train loss 1.7683, val loss 1.9298
# step 950: train loss 1.7681, val loss 1.9140
# step 1000: train loss 1.7639, val loss 1.9161
# step 1050: train loss 1.7347, val loss 1.9112
# step 1100: train loss 1.7665, val loss 1.9071
# step 1150: train loss 1.7551, val loss 1.9123
# step 1200: train loss 1.7517, val loss 1.8910
# step 1250: train loss 1.7522, val loss 1.9033
# step 1300: train loss 1.7509, val loss 1.8851
# step 1350: train loss 1.7474, val loss 1.8793
# step 1400: train loss 1.7437, val loss 1.8884
# step 1450: train loss 1.7569, val loss 1.8746
# step 1500: train loss 1.7430, val loss 1.9060
# step 1550: train loss 1.7650, val loss 1.9086
# step 1600: train loss 1.7571, val loss 1.8962
# step 1650: train loss 1.7544, val loss 1.8990
# step 1700: train loss 1.7514, val loss 1.9175
# step 1750: train loss 1.7356, val loss 1.8801
# step 1800: train loss 1.7388, val loss 1.8692
# step 1850: train loss 1.7350, val loss 1.9024
# step 1900: train loss 1.7508, val loss 1.9109
# step 1950: train loss 1.7393, val loss 1.8898
# step 2000: train loss 1.7603, val loss 1.9264
# step 2050: train loss 1.7470, val loss 1.8965
# step 2100: train loss 1.7338, val loss 1.8901
# step 2150: train loss 1.7332, val loss 1.8876
# step 2200: train loss 1.7334, val loss 1.9152
# step 2250: train loss 1.7291, val loss 1.8971
# step 2300: train loss 1.7195, val loss 1.8783
# step 2350: train loss 1.7432, val loss 1.8787
# step 2400: train loss 1.7334, val loss 1.8842
# step 2450: train loss 1.7253, val loss 1.9030
# step 2500: train loss 1.7517, val loss 1.8698
# step 2550: train loss 1.7270, val loss 1.8796
# step 2600: train loss 1.7296, val loss 1.8904
# step 2650: train loss 1.7198, val loss 1.9018
# step 2700: train loss 1.7340, val loss 1.8781
# step 2750: train loss 1.7301, val loss 1.8946
# step 2800: train loss 1.7028, val loss 1.8370
# step 2850: train loss 1.7357, val loss 1.8860
# step 2900: train loss 1.7212, val loss 1.8881
# step 2950: train loss 1.7196, val loss 1.8742
# step 3000: train loss 1.7193, val loss 1.8823
# step 3050: train loss 1.7078, val loss 1.8635
# step 3100: train loss 1.7200, val loss 1.8695
# step 3150: train loss 1.6879, val loss 1.8849
# step 3200: train loss 1.7265, val loss 1.8749
# step 3250: train loss 1.7193, val loss 1.8590
# step 3300: train loss 1.7111, val loss 1.8671
# step 3350: train loss 1.6920, val loss 1.8611
# step 3400: train loss 1.7113, val loss 1.8611
# step 3450: train loss 1.7121, val loss 1.8765
# step 3500: train loss 1.7066, val loss 1.8788
# step 3550: train loss 1.7201, val loss 1.8681
# step 3600: train loss 1.6936, val loss 1.8567
# step 3650: train loss 1.6939, val loss 1.8569
# step 3700: train loss 1.7150, val loss 1.8694
# step 3750: train loss 1.7033, val loss 1.8567
# step 3800: train loss 1.7052, val loss 1.8506
# step 3850: train loss 1.7038, val loss 1.8620
# step 3900: train loss 1.7176, val loss 1.8844
# step 3950: train loss 1.7110, val loss 1.8568
# step 4000: train loss 1.6904, val loss 1.8627
# step 4050: train loss 1.6746, val loss 1.8721
# step 4100: train loss 1.6881, val loss 1.8532
# step 4150: train loss 1.7021, val loss 1.8576
# step 4200: train loss 1.7072, val loss 1.8561
# step 4250: train loss 1.7022, val loss 1.8496
# step 4300: train loss 1.7203, val loss 1.8308
# step 4350: train loss 1.6952, val loss 1.8222
# step 4400: train loss 1.7158, val loss 1.8484
# step 4450: train loss 1.6761, val loss 1.8263
# step 4500: train loss 1.7004, val loss 1.8682
# step 4550: train loss 1.6946, val loss 1.8550
# step 4600: train loss 1.7040, val loss 1.8645
# step 4650: train loss 1.6844, val loss 1.8347
# step 4700: train loss 1.6758, val loss 1.8591
# step 4750: train loss 1.6840, val loss 1.8307
# step 4800: train loss 1.6762, val loss 1.8403
# step 4850: train loss 1.6874, val loss 1.8363
# step 4900: train loss 1.6897, val loss 1.8595
# step 4950: train loss 1.6943, val loss 1.8620
# step 5000: train loss 1.6812, val loss 1.8474
# step 5050: train loss 1.6759, val loss 1.8541
# step 5100: train loss 1.7107, val loss 1.8779
# step 5150: train loss 1.6860, val loss 1.8441
# step 5200: train loss 1.6692, val loss 1.8338
# step 5250: train loss 1.6832, val loss 1.8426
# step 5300: train loss 1.6926, val loss 1.8405
# step 5350: train loss 1.6695, val loss 1.8251
# step 5400: train loss 1.6690, val loss 1.8562
# step 5450: train loss 1.6795, val loss 1.8373
# step 5500: train loss 1.6715, val loss 1.8456
# step 5550: train loss 1.6707, val loss 1.8614
# step 5600: train loss 1.6812, val loss 1.8375
# step 5650: train loss 1.6847, val loss 1.8539
# step 5700: train loss 1.6606, val loss 1.8391
# step 5750: train loss 1.6853, val loss 1.8237
# step 5800: train loss 1.6959, val loss 1.8354
# step 5850: train loss 1.6822, val loss 1.8413
# step 5900: train loss 1.6753, val loss 1.8397
# step 5950: train loss 1.6541, val loss 1.8227
# step 6000: train loss 1.6787, val loss 1.8409
# step 6050: train loss 1.6684, val loss 1.8148
# step 6100: train loss 1.6710, val loss 1.8649
# step 6150: train loss 1.6644, val loss 1.8227
# step 6200: train loss 1.6750, val loss 1.8477
# step 6250: train loss 1.6788, val loss 1.8315
# step 6300: train loss 1.6799, val loss 1.8077
# step 6350: train loss 1.6638, val loss 1.8267
# step 6400: train loss 1.6467, val loss 1.8336
# step 6450: train loss 1.6630, val loss 1.8351
# step 6500: train loss 1.6729, val loss 1.8155
# step 6550: train loss 1.6698, val loss 1.8257
# step 6600: train loss 1.6478, val loss 1.8329
# step 6650: train loss 1.6525, val loss 1.8020
# step 6700: train loss 1.6438, val loss 1.8071
# step 6750: train loss 1.6608, val loss 1.8401
# step 6800: train loss 1.6656, val loss 1.8262
# step 6850: train loss 1.6598, val loss 1.8408
# step 6900: train loss 1.6636, val loss 1.8038
# step 6950: train loss 1.6557, val loss 1.7786
# step 7000: train loss 1.6543, val loss 1.8051
# step 7050: train loss 1.6595, val loss 1.8140
# step 7100: train loss 1.6466, val loss 1.8221
# step 7150: train loss 1.6592, val loss 1.8185
# step 7200: train loss 1.6610, val loss 1.8059
# step 7250: train loss 1.6495, val loss 1.8057
# step 7300: train loss 1.6658, val loss 1.8075
# step 7350: train loss 1.6759, val loss 1.8083
# step 7400: train loss 1.6622, val loss 1.8172
# step 7450: train loss 1.6608, val loss 1.8069
# step 7500: train loss 1.6495, val loss 1.8304
# step 7550: train loss 1.6721, val loss 1.8113
# step 7600: train loss 1.6489, val loss 1.8247
# step 7650: train loss 1.6505, val loss 1.7895
# step 7700: train loss 1.6381, val loss 1.8148
# step 7750: train loss 1.6370, val loss 1.8064
# step 7800: train loss 1.6382, val loss 1.7963
# step 7850: train loss 1.6660, val loss 1.8105
# step 7900: train loss 1.6239, val loss 1.8048
# step 7950: train loss 1.6475, val loss 1.7981
# step 8000: train loss 1.6487, val loss 1.8191
# step 8050: train loss 1.6502, val loss 1.8244
# step 8100: train loss 1.6404, val loss 1.8006
# step 8150: train loss 1.6400, val loss 1.8113
# step 8200: train loss 1.6439, val loss 1.8033
# step 8250: train loss 1.6353, val loss 1.8219
# step 8300: train loss 1.6434, val loss 1.8004
# step 8350: train loss 1.6518, val loss 1.8071
# step 8400: train loss 1.6394, val loss 1.7922
# step 8450: train loss 1.6299, val loss 1.8090
# step 8500: train loss 1.6437, val loss 1.8065
# step 8550: train loss 1.6369, val loss 1.7863
# step 8600: train loss 1.6322, val loss 1.8137
# step 8650: train loss 1.6382, val loss 1.8169
# step 8700: train loss 1.6400, val loss 1.8242
# step 8750: train loss 1.6340, val loss 1.7878
# step 8800: train loss 1.6410, val loss 1.8086
# step 8850: train loss 1.6249, val loss 1.7810
# step 8900: train loss 1.6355, val loss 1.8062
# step 8950: train loss 1.6451, val loss 1.8135
# step 9000: train loss 1.6288, val loss 1.8171
# step 9050: train loss 1.6450, val loss 1.7850
# step 9100: train loss 1.6297, val loss 1.7909
# step 9150: train loss 1.6424, val loss 1.7862
# step 9200: train loss 1.6494, val loss 1.8004
# step 9250: train loss 1.6379, val loss 1.7972
# step 9300: train loss 1.6396, val loss 1.8017
# step 9350: train loss 1.6299, val loss 1.7753
# step 9400: train loss 1.6340, val loss 1.7922
# step 9450: train loss 1.6486, val loss 1.7909
# step 9500: train loss 1.6339, val loss 1.7899
# step 9550: train loss 1.6321, val loss 1.7765
# step 9600: train loss 1.6280, val loss 1.8164
# step 9650: train loss 1.6437, val loss 1.7870
# step 9700: train loss 1.6210, val loss 1.7857
# step 9750: train loss 1.6175, val loss 1.7910
# step 9800: train loss 1.6223, val loss 1.7785
# step 9850: train loss 1.6207, val loss 1.7938
# step 9900: train loss 1.6307, val loss 1.8138
# step 9950: train loss 1.6193, val loss 1.8053
# step 9999: train loss 1.6394, val loss 1.7959

# %%
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(mod.generate(context, max_new_tokens=500)[0].tolist()))
# Out:
# Ay. Margaret, in the destrens! king be!
# He could mallen and nottly:
# and, die not, good ney:
# Twice, sir? fair; you shall rove me drask?
# Whoe more post call the love;
# And when must the send
# Doth our to schess ang, and shrands which the toast an do not:
# To have hunce anothe
# to Lords, the fuled, made forlal of the portedille
# Proqued, for should hit, which Englings his depossent know.
# Cheep deid yield doth belike 'Will his uttime
# With sit.
#
# GLOUCESTER:
# I see think summmservall child bawg keep so rece

# %%
torch.save(mod, 'model_01022023')
